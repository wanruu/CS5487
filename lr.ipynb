# %% [markdown]
# <a href="https://colab.research.google.com/github/wanruu/CS5487/blob/main/lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
#from config import DIGITS_MAT_PATH
from data import MyDataset
from utils import accuracy
import tqdm

# import cv2
DIGITS_MAT_PATH = '/content/digits4000.mat'
train_dataset = MyDataset(DIGITS_MAT_PATH, "mat", True, 0)
test_dataset = MyDataset(DIGITS_MAT_PATH, "mat", False, 0)

X_train = train_dataset.imgs.T
y_train = train_dataset.labels.T
X_test = test_dataset.imgs.T
y_test = test_dataset.labels.T

pca_n=[]
acc=[]
for i in tqdm.tqdm(range(78)):
  
  pca = PCA(n_components=(i+1)*10)
  pca_X_train = pca.fit_transform(X_train)
  pca_X_test = pca.transform(X_test)

  # train_data = DataLoader(train_dataset, batch_size=1,
  #                         shuffle=False, num_workers=0)


  # for img, label in train_data:
  #     # plt.figure(figsize=(20,4))
  #     # plt.imshow(np.reshape(img, (28,28)), cmap=plt.cm.gray)
  #     print(img.reshape(28, 28).shape)
  #     cv2.imshow("", np.array(img.reshape(28, 28)))
  #     cv2.waitKey(0)
  #     break

  clf = LogisticRegression(fit_intercept=True,
                          multi_class='auto',
                          penalty='l2',  # ridge regression
                          solver='saga',
                          max_iter=10000,
                          C=50)
  clf.fit(pca_X_train, y_train)

  y_predict = clf.predict(pca_X_test)
  #print(accuracy(y_test,y_predict))
  pca_n.append((i+1)*10)
  acc.append(accuracy(y_test,y_predict))

plt.figure(figsize=(10, 10))
plt.plot(pca_n,acc)

plt.xlabel('pca_components')
plt.ylabel('acc')
plt.title('pca_lr')
plt.legend()
plt.show

#best pca
idx=acc.index(max(acc))
print([pca_n[idx],max(acc)])
# Out:
#   0%|          | 0/78 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   1%|▏         | 1/78 [00:00<00:10,  7.41it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   3%|▎         | 2/78 [00:00<00:16,  4.70it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   4%|▍         | 3/78 [00:00<00:23,  3.16it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   5%|▌         | 4/78 [00:01<00:41,  1.80it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   6%|▋         | 5/78 [00:07<02:47,  2.30s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   8%|▊         | 6/78 [00:13<04:34,  3.81s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   9%|▉         | 7/78 [00:40<13:24, 11.32s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  10%|█         | 8/78 [01:06<18:45, 16.08s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  12%|█▏        | 9/78 [01:28<20:29, 17.82s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  13%|█▎        | 10/78 [01:49<21:14, 18.74s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  14%|█▍        | 11/78 [02:09<21:31, 19.27s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  15%|█▌        | 12/78 [02:29<21:17, 19.36s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  17%|█▋        | 13/78 [02:49<21:19, 19.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  18%|█▊        | 14/78 [03:11<21:46, 20.41s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  19%|█▉        | 15/78 [03:33<21:47, 20.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  21%|██        | 16/78 [03:56<22:03, 21.34s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  22%|██▏       | 17/78 [04:20<22:29, 22.12s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  23%|██▎       | 18/78 [04:44<22:41, 22.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  24%|██▍       | 19/78 [05:08<22:54, 23.30s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  26%|██▌       | 20/78 [05:35<23:32, 24.35s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  27%|██▋       | 21/78 [06:02<23:47, 25.05s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  28%|██▊       | 22/78 [06:29<24:05, 25.81s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  29%|██▉       | 23/78 [06:58<24:20, 26.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  31%|███       | 24/78 [07:27<24:37, 27.37s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  32%|███▏      | 25/78 [07:58<25:12, 28.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  33%|███▎      | 26/78 [08:29<25:24, 29.33s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  35%|███▍      | 27/78 [09:03<25:55, 30.49s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  36%|███▌      | 28/78 [09:37<26:17, 31.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  37%|███▋      | 29/78 [10:11<26:24, 32.34s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  38%|███▊      | 30/78 [10:46<26:32, 33.18s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  40%|███▉      | 31/78 [11:22<26:35, 33.95s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  41%|████      | 32/78 [11:58<26:38, 34.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  42%|████▏     | 33/78 [12:36<26:46, 35.70s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  44%|████▎     | 34/78 [13:15<26:49, 36.58s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  45%|████▍     | 35/78 [13:56<27:04, 37.79s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  46%|████▌     | 36/78 [14:38<27:29, 39.28s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  47%|████▋     | 37/78 [15:20<27:16, 39.92s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  49%|████▊     | 38/78 [16:02<27:06, 40.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  50%|█████     | 39/78 [16:48<27:25, 42.19s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  51%|█████▏    | 40/78 [17:33<27:12, 42.95s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  53%|█████▎    | 41/78 [18:19<27:07, 43.99s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  54%|█████▍    | 42/78 [19:06<26:55, 44.87s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  55%|█████▌    | 43/78 [19:54<26:39, 45.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  56%|█████▋    | 44/78 [20:42<26:24, 46.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  58%|█████▊    | 45/78 [21:32<26:10, 47.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  59%|█████▉    | 46/78 [22:23<25:56, 48.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  60%|██████    | 47/78 [23:16<25:45, 49.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  62%|██████▏   | 48/78 [24:09<25:22, 50.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  63%|██████▎   | 49/78 [25:03<25:01, 51.79s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  64%|██████▍   | 50/78 [25:58<24:36, 52.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  65%|██████▌   | 51/78 [26:54<24:10, 53.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  67%|██████▋   | 52/78 [27:51<23:42, 54.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  68%|██████▊   | 53/78 [28:52<23:34, 56.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  69%|██████▉   | 54/78 [29:52<23:00, 57.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  71%|███████   | 55/78 [30:52<22:21, 58.33s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  72%|███████▏  | 56/78 [31:55<21:57, 59.87s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  73%|███████▎  | 57/78 [32:58<21:16, 60.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  74%|███████▍  | 58/78 [34:03<20:37, 61.88s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  76%|███████▌  | 59/78 [35:10<20:05, 63.46s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  77%|███████▋  | 60/78 [36:16<19:17, 64.32s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  78%|███████▊  | 61/78 [37:23<18:25, 65.05s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  79%|███████▉  | 62/78 [38:32<17:39, 66.20s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  81%|████████  | 63/78 [39:43<16:53, 67.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  82%|████████▏ | 64/78 [40:51<15:51, 67.96s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  83%|████████▎ | 65/78 [42:02<14:53, 68.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  85%|████████▍ | 66/78 [43:16<14:05, 70.46s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  86%|████████▌ | 67/78 [44:30<13:05, 71.37s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  87%|████████▋ | 68/78 [45:44<12:00, 72.10s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  88%|████████▊ | 69/78 [47:01<11:02, 73.64s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  90%|████████▉ | 70/78 [48:17<09:54, 74.27s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  91%|█████████ | 71/78 [49:34<08:47, 75.30s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  92%|█████████▏| 72/78 [50:54<07:40, 76.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  94%|█████████▎| 73/78 [52:13<06:26, 77.23s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  95%|█████████▍| 74/78 [53:34<05:13, 78.42s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  96%|█████████▌| 75/78 [55:02<04:03, 81.28s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  97%|█████████▋| 76/78 [56:24<02:43, 81.50s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  99%|█████████▊| 77/78 [57:49<01:22, 82.42s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 100%|██████████| 78/78 [59:16<00:00, 45.60s/it]
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# [40, 0.8755]

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
#from config import DIGITS_MAT_PATH
from data import MyDataset
from utils import accuracy
import tqdm

# import cv2
DIGITS_MAT_PATH = '/content/digits4000.mat'
train_dataset = MyDataset(DIGITS_MAT_PATH, "mat", True, 0)
test_dataset = MyDataset(DIGITS_MAT_PATH, "mat", False, 0)

X_train = train_dataset.imgs.T
y_train = train_dataset.labels.T
X_test = test_dataset.imgs.T
y_test = test_dataset.labels.T

pca_n=[]
acc=[]
for i in tqdm.tqdm(range(20)):
  
  pca = PCA(n_components=(i+30))
  pca_X_train = pca.fit_transform(X_train)
  pca_X_test = pca.transform(X_test)

  # train_data = DataLoader(train_dataset, batch_size=1,
  #                         shuffle=False, num_workers=0)


  # for img, label in train_data:
  #     # plt.figure(figsize=(20,4))
  #     # plt.imshow(np.reshape(img, (28,28)), cmap=plt.cm.gray)
  #     print(img.reshape(28, 28).shape)
  #     cv2.imshow("", np.array(img.reshape(28, 28)))
  #     cv2.waitKey(0)
  #     break

  clf = LogisticRegression(fit_intercept=True,
                          multi_class='auto',
                          penalty='l2',  # ridge regression
                          solver='saga',
                          max_iter=10000,
                          C=50)
  clf.fit(pca_X_train, y_train)

  y_predict = clf.predict(pca_X_test)
  #print(accuracy(y_test,y_predict))
  pca_n.append((i+30))
  acc.append(accuracy(y_test,y_predict))

plt.figure(figsize=(10, 10))
plt.plot(pca_n,acc)

plt.xlabel('pca_components')
plt.ylabel('acc')
plt.title('pca_lr')
plt.legend()
plt.show

#best pca
idx=acc.index(max(acc))
print([pca_n[idx],max(acc)])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   5%|▌         | 1/20 [00:00<00:08,  2.33it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  10%|█         | 2/20 [00:00<00:08,  2.15it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  15%|█▌        | 3/20 [00:01<00:08,  1.91it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  20%|██        | 4/20 [00:02<00:08,  1.82it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  25%|██▌       | 5/20 [00:02<00:08,  1.72it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  30%|███       | 6/20 [00:03<00:08,  1.63it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  35%|███▌      | 7/20 [00:04<00:08,  1.54it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  40%|████      | 8/20 [00:04<00:08,  1.47it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  45%|████▌     | 9/20 [00:05<00:08,  1.37it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  50%|█████     | 10/20 [00:06<00:07,  1.29it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  55%|█████▌    | 11/20 [00:07<00:07,  1.23it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  60%|██████    | 12/20 [00:08<00:07,  1.11it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  65%|██████▌   | 13/20 [00:09<00:06,  1.02it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  70%|███████   | 14/20 [00:10<00:06,  1.05s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  75%|███████▌  | 15/20 [00:12<00:05,  1.12s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  80%|████████  | 16/20 [00:13<00:04,  1.19s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  85%|████████▌ | 17/20 [00:15<00:03,  1.31s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  90%|█████████ | 18/20 [00:16<00:02,  1.42s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#  95%|█████████▌| 19/20 [00:18<00:01,  1.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 100%|██████████| 20/20 [00:20<00:00,  1.03s/it]
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# [37, 0.8755]

# %%
#trail 2
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
#from config import DIGITS_MAT_PATH
from data import MyDataset
from utils import accuracy
import tqdm

# import cv2
DIGITS_MAT_PATH = '/content/digits4000.mat'
train_dataset = MyDataset(DIGITS_MAT_PATH, "mat", True, 0)
test_dataset = MyDataset(DIGITS_MAT_PATH, "mat", False, 0)

X_train = test_dataset.imgs.T
y_train = test_dataset.labels.T
X_test = train_dataset.imgs.T
y_test = train_dataset.labels.T

pca_n=[]
acc=[]
for i in tqdm.tqdm(range(1)):
  
  pca = PCA(n_components=(37))
  pca_X_train = pca.fit_transform(X_train)
  pca_X_test = pca.transform(X_test)

  # train_data = DataLoader(train_dataset, batch_size=1,
  #                         shuffle=False, num_workers=0)


  # for img, label in train_data:
  #     # plt.figure(figsize=(20,4))
  #     # plt.imshow(np.reshape(img, (28,28)), cmap=plt.cm.gray)
  #     print(img.reshape(28, 28).shape)
  #     cv2.imshow("", np.array(img.reshape(28, 28)))
  #     cv2.waitKey(0)
  #     break

  clf = LogisticRegression(fit_intercept=True,
                          multi_class='auto',
                          penalty='l2',  # ridge regression
                          solver='saga',
                          max_iter=10000,
                          C=50)
  clf.fit(pca_X_train, y_train)

  y_predict = clf.predict(pca_X_test)
  #print(accuracy(y_test,y_predict))
  pca_n.append((37))
  acc.append(accuracy(y_test,y_predict))



#best pca
idx=acc.index(max(acc))
print('\n')
print([pca_n[idx],max(acc)])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# [37, 0.864]

# %%
! git clone https://github.com/wanruu/CS5487.git
# Out:
# Cloning into 'CS5487'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 110 (delta 53), reused 46 (delta 20), pack-reused 0
# Receiving objects: 100% (110/110), 343.20 KiB | 16.34 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
